# %%
# %sql
-- Célula SQL no Notebook
-- Cria um Volume chamado 'kdd_volume' dentro do seu catálogo padrão

CREATE VOLUME IF NOT EXISTS bigdata_anomaly_detection_kddcup99_catalogue.default.kdd_volume;

-- Agora, vamos confirmar a criação
SELECT * FROM system.information_schema.volumes 
WHERE volume_name = 'kdd_volume';
